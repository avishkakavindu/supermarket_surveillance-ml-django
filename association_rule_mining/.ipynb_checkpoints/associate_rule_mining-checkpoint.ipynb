# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./dataset/basket.csv')
df.head(50)
# Out:
#                      0                    1                          2  \
# 0           whole milk               pastry                salty snack
# 1              sausage           whole milk        semi-finished bread
# 2                 soda   pickled vegetables                        NaN
# 3          canned beer      misc. beverages                        NaN
# 4              sausage     hygiene articles                        NaN
# 5              sausage           whole milk                 rolls/buns
# 6           whole milk                 soda                        NaN
# 7          frankfurter                 soda         whipped/sour cream
# 8          frankfurter                 curd                        NaN
# 9                 beef          white bread                        NaN
# 10              butter           whole milk                        NaN
# 11   frozen vegetables     other vegetables                        NaN
# 12      tropical fruit                sugar                        NaN
# 13         butter milk  specialty chocolate                        NaN
# 14        frozen meals          dental care                        NaN
# 15          rolls/buns           rolls/buns                        NaN
# 16     root vegetables            detergent                        NaN
# 17             sausage           rolls/buns                        NaN
# 18        dish cleaner      cling film/bags                        NaN
# 19         canned beer          frozen fish                        NaN
# 20           pip fruit           whole milk             tropical fruit
# 21     root vegetables           whole milk                     pastry
# 22          rolls/buns       red/blush wine                  chocolate
# 23    other vegetables        shopping bags                        NaN
# 24          whole milk            chocolate  packaged fruit/vegetables
# 25    other vegetables     hygiene articles                        NaN
# 26  whipped/sour cream            margarine                        NaN
# 27          rolls/buns           rolls/buns                        NaN
# 28       bottled water             softener                 rolls/buns
# 29          whole milk                 rice                        NaN
# 30       shopping bags            skin care                        NaN
# 31          whole milk          frankfurter                    chicken
# 32      hamburger meat   liquor (appetizer)                 liver loaf
# 33      tropical fruit                 soda                     yogurt
# 34         canned fish         cocoa drinks                        NaN
# 35               herbs               yogurt                 newspapers
# 36      tropical fruit               yogurt                        NaN
# 37              pastry              ketchup                        NaN
# 38           pip fruit               coffee                   UHT-milk
# 39       bottled water        specialty bar                        NaN
# 40         frankfurter        bottled water                        NaN
# 41      kitchen towels        sliced cheese                        NaN
# 42           pip fruit              candles                 rolls/buns
# 43         curd cheese               pastry                        NaN
# 44        citrus fruit                candy              bottled water
# 45          whole milk          frankfurter                    candles
# 46   frozen vegetables          brown bread                        NaN
# 47         frankfurter               yogurt                        NaN
# 48    processed cheese           whole milk                        NaN
# 49      tropical fruit      root vegetables                 rolls/buns
#
#                   3              4                 5             6  \
# 0               NaN            NaN               NaN           NaN
# 1            yogurt            NaN               NaN           NaN
# 2               NaN            NaN               NaN           NaN
# 3               NaN            NaN               NaN           NaN
# 4               NaN            NaN               NaN           NaN
# 5               NaN            NaN               NaN           NaN
# 6               NaN            NaN               NaN           NaN
# 7               NaN            NaN               NaN           NaN
# 8               NaN            NaN               NaN           NaN
# 9               NaN            NaN               NaN           NaN
# 10              NaN            NaN               NaN           NaN
# 11              NaN            NaN               NaN           NaN
# 12              NaN            NaN               NaN           NaN
# 13              NaN            NaN               NaN           NaN
# 14              NaN            NaN               NaN           NaN
# 15              NaN            NaN               NaN           NaN
# 16              NaN            NaN               NaN           NaN
# 17              NaN            NaN               NaN           NaN
# 18              NaN            NaN               NaN           NaN
# 19              NaN            NaN               NaN           NaN
# 20              NaN            NaN               NaN           NaN
# 21              NaN            NaN               NaN           NaN
# 22              NaN            NaN               NaN           NaN
# 23              NaN            NaN               NaN           NaN
# 24       rolls/buns            NaN               NaN           NaN
# 25              NaN            NaN               NaN           NaN
# 26              NaN            NaN               NaN           NaN
# 27              NaN            NaN               NaN           NaN
# 28              NaN            NaN               NaN           NaN
# 29              NaN            NaN               NaN           NaN
# 30              NaN            NaN               NaN           NaN
# 31      frankfurter          flour         chocolate  bottled beer
# 32          dessert            NaN               NaN           NaN
# 33  root vegetables         yogurt     domestic eggs    white wine
# 34              NaN            NaN               NaN           NaN
# 35              NaN            NaN               NaN           NaN
# 36              NaN            NaN               NaN           NaN
# 37              NaN            NaN               NaN           NaN
# 38              NaN            NaN               NaN           NaN
# 39              NaN            NaN               NaN           NaN
# 40              NaN            NaN               NaN           NaN
# 41              NaN            NaN               NaN           NaN
# 42              NaN            NaN               NaN           NaN
# 43              NaN            NaN               NaN           NaN
# 44       rolls/buns            NaN               NaN           NaN
# 45           grapes          herbs  other vegetables        yogurt
# 46              NaN            NaN               NaN           NaN
# 47              NaN            NaN               NaN           NaN
# 48              NaN            NaN               NaN           NaN
# 49           onions  shopping bags               NaN           NaN
#
#              7    8    9   10
# 0          NaN  NaN  NaN  NaN
# 1          NaN  NaN  NaN  NaN
# 2          NaN  NaN  NaN  NaN
# 3          NaN  NaN  NaN  NaN
# 4          NaN  NaN  NaN  NaN
# 5          NaN  NaN  NaN  NaN
# 6          NaN  NaN  NaN  NaN
# 7          NaN  NaN  NaN  NaN
# 8          NaN  NaN  NaN  NaN
# 9          NaN  NaN  NaN  NaN
# 10         NaN  NaN  NaN  NaN
# 11         NaN  NaN  NaN  NaN
# 12         NaN  NaN  NaN  NaN
# 13         NaN  NaN  NaN  NaN
# 14         NaN  NaN  NaN  NaN
# 15         NaN  NaN  NaN  NaN
# 16         NaN  NaN  NaN  NaN
# 17         NaN  NaN  NaN  NaN
# 18         NaN  NaN  NaN  NaN
# 19         NaN  NaN  NaN  NaN
# 20         NaN  NaN  NaN  NaN
# 21         NaN  NaN  NaN  NaN
# 22         NaN  NaN  NaN  NaN
# 23         NaN  NaN  NaN  NaN
# 24         NaN  NaN  NaN  NaN
# 25         NaN  NaN  NaN  NaN
# 26         NaN  NaN  NaN  NaN
# 27         NaN  NaN  NaN  NaN
# 28         NaN  NaN  NaN  NaN
# 29         NaN  NaN  NaN  NaN
# 30         NaN  NaN  NaN  NaN
# 31  rolls/buns  NaN  NaN  NaN
# 32         NaN  NaN  NaN  NaN
# 33  photo/film  NaN  NaN  NaN
# 34         NaN  NaN  NaN  NaN
# 35         NaN  NaN  NaN  NaN
# 36         NaN  NaN  NaN  NaN
# 37         NaN  NaN  NaN  NaN
# 38         NaN  NaN  NaN  NaN
# 39         NaN  NaN  NaN  NaN
# 40         NaN  NaN  NaN  NaN
# 41         NaN  NaN  NaN  NaN
# 42         NaN  NaN  NaN  NaN
# 43         NaN  NaN  NaN  NaN
# 44         NaN  NaN  NaN  NaN
# 45         NaN  NaN  NaN  NaN
# 46         NaN  NaN  NaN  NaN
# 47         NaN  NaN  NaN  NaN
# 48         NaN  NaN  NaN  NaN
# 49         NaN  NaN  NaN  NaN

# %%
data = df.T.apply(lambda x: x.dropna().values.tolist()).values.tolist()
data
# Out:
# 0                        [whole milk, pastry, salty snack]
# 1        [sausage, whole milk, semi-finished bread, yog...
# 2                               [soda, pickled vegetables]
# 3                           [canned beer, misc. beverages]
# 4                              [sausage, hygiene articles]
#                                ...
# 14958                    [butter milk, whipped/sour cream]
# 14959                               [bottled water, herbs]
# 14960                      [fruit/vegetable juice, onions]
# 14961                     [bottled beer, other vegetables]
# 14962         [soda, root vegetables, semi-finished bread]
# Length: 14963, dtype: object

# %%
data
# Out:
# 0                        [whole milk, pastry, salty snack]
# 1        [sausage, whole milk, semi-finished bread, yog...
# 2                               [soda, pickled vegetables]
# 3                           [canned beer, misc. beverages]
# 4                              [sausage, hygiene articles]
#                                ...
# 14958                    [butter milk, whipped/sour cream]
# 14959                               [bottled water, herbs]
# 14960                      [fruit/vegetable juice, onions]
# 14961                     [bottled beer, other vegetables]
# 14962         [soda, root vegetables, semi-finished bread]
# Length: 14963, dtype: object
